# %%
import sys
from pathlib import Path

# ────────────────────────────────────────────────
notebook_dir = Path.cwd().resolve()
project_root = notebook_dir.parent.parent  # adjust levels as needed
sys.path.insert(0, str(notebook_dir))
sys.path.insert(0, str(notebook_dir.parent))
sys.path.insert(0, str(project_root))

# ────────────────────────────────────────────────
# 3. Custom helpers / local modules
# ────────────────────────────────────────────────
from solver_helpers import merge_sww_files, merge_sww_files_parallel_parts

# %%
merge_sww_files(directory='results', output_name='merged2.sww', 
                           delete_originals=False, verbose=True)
# Out:
# ...
# MERGING & WELDING 20 FILES
# ...
#   Reading file 0...
#   Reading file 5...
#   Reading file 10...
#   Reading file 15...
# ✓ Merge Complete: 64587 unique nodes identified (from 71146).
# 'results/merged2.sww'
